# %% [markdown]
# **Implementasi 1**

# %% [markdown]
# Metode kovensional

# %%
print("Metode Konvensional:")
for x in range(-4, 5):
    print("f(",x,") = ",3*x - 7)
# Out:
# Metode Konvensional:
# f( -4 ) =  -19
# f( -3 ) =  -16
# f( -2 ) =  -13
# f( -1 ) =  -10
# f( 0 ) =  -7
# f( 1 ) =  -4
# f( 2 ) =  -1
# f( 3 ) =  2
# f( 4 ) =  5

# %% [markdown]
# Dengan menggunakan def

# %%
print("Menggunakan def:")
def f(x):
    return 3*x - 7
for x in range(-4, 5):
    print("f(",x,") = ",f(x))
# Out:
# Menggunakan def:
# f( -4 ) =  -19
# f( -3 ) =  -16
# f( -2 ) =  -13
# f( -1 ) =  -10
# f( 0 ) =  -7
# f( 1 ) =  -4
# f( 2 ) =  -1
# f( 3 ) =  2
# f( 4 ) =  5

# %% [markdown]
# Menuliskan anggota himpunan di domain dengan menggunakan list

# %%
print("Menggunakan domain list:")
def fx (x):
  return (3 * x) - 7
domain = [i for i in range (-4,5)]
for j in domain:
  print ("f(",j,") = ",fx(j))
# Out:
# f( -4 ) =  -19
# f( -3 ) =  -16
# f( -2 ) =  -13
# f( -1 ) =  -10
# f( 0 ) =  -7
# f( 1 ) =  -4
# f( 2 ) =  -1
# f( 3 ) =  2
# f( 4 ) =  5

# %% [markdown]
# **Implementasi 2**

# %% [markdown]
# a). f(x) = 2x | -100 < x < 100

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-99, 99, 400)
y = 2 * x

plt.figure(figsize=(8,5))
plt.plot(x, y, label="f(x) = 2x", color="blue")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.title("Grafik f(x) = 2x", color="blue")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# b). f(x) = x**2 + 3x - 10 | -20 < x < 20

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-19, 19, 400)
y = x**2 + 3*x - 10

plt.figure(figsize=(8,5))
plt.plot(x, y, label="f(x) = x² + 3x - 10", color="green")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.title("Grafik f(x) = x² + 3x - 10", color="green")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# c). f(x) = x**3 - 10 | -10 < x < 10

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-9, 9, 400)
y = x**3 - 10

plt.figure(figsize=(8,5))
plt.plot(x, y, label="f(x) = x³ - 10", color="purple")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.title("Grafik f(x) = x³ - 10", color="purple")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# d). f(x) = sin(x) | -2π < x 2π

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2*np.pi, 2*np.pi, 400)
y = np.sin(x)

plt.figure(figsize=(8,5))
plt.plot(x, y, label="f(x) = sin(x)", color="red")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.title("Grafik f(x) = sin(x)", color="red")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# e). f(x) = cos(x) | -2 π  < x 2π

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2*np.pi, 2*np.pi, 400)
y = np.cos(x)

plt.figure(figsize=(8,5))
plt.plot(x, y, label="f(x) = cos(x)", color="orange")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.title("Grafik f(x) = cos(x)", color="orange")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()
